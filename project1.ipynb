# %% [markdown]
# <a href="https://colab.research.google.com/github/mistershadow001/Data-Science-/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **CSV_section**

# %%
customers = files.upload()
# Out:
#      <input type="file" id="files-1492e5ca-82b8-4ac9-bbce-1eb7ee2266a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1492e5ca-82b8-4ac9-bbce-1eb7ee2266a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# customers.csv  sample_data/

# %%
c1=pd.read_csv("customers.csv")
c1.head()
# Out:
#    'custno' 'firstname' 'lastname' 'gender'  'age' 'profession'  'contactNo'  \
# 0         1      Leslie       Bass        F     27            B        37307
# 1         2        Judy      Burks        M     53            S        84759
# 2         3      Marsha      Doyle        F     48            B        80932
# 3         4      Alexis     Battle        M     27            S        71701
# 4         5      Martha      Combs        F     49            B        83947
#
#                 'emailId'   'city'    'state' 'isActive'        'createdDate'  \
# 0  endslost@everyma1l.org   Gibson   Dellwood          Y  2017-09-21 12:38:22
# 1  rfleming@hotma1l.co.uk  Suwanee     Trabue          Y  2017-05-22 05:29:22
# 2    arethe53@ma1lbox.net    Perry  Moxadarla          Y  2017-09-03 12:11:29
# 3      ofcame@ma1lbox.org   Morven     Dennis          Y  2017-02-16 04:05:35
# 4   camedied@everyma1l.us   Ocilla  Greenwood          Y  2017-05-15 07:34:35
#
#          'UpdatedDate'
# ...

# %%
transactions = files.upload()
# Out:
#      <input type="file" id="files-39ed1faa-5c8f-4a1d-8efd-fa3f6cd5295a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39ed1faa-5c8f-4a1d-8efd-fa3f6cd5295a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
t1=pd.read_csv("transactions.csv")
t1.head()
# Out:
#    'txnno'            'txndate'  'custno'  'amount'  'productno' 'spendby'
# 0        1  2017-10-18 12:31:45       923      2559          376      Card
# 1        2  2017-10-18 12:31:45       219      1706          151      Card
# 2        3  2017-10-18 12:31:45       927      3462          707      Cash
# 3        4  2017-10-18 12:31:45       806       865          539      Card
# 4        5  2017-10-18 12:31:45       958      2494           25      Card

# %%
product=files.upload()
# Out:
#      <input type="file" id="files-5e081a63-ed78-4b88-8e50-1a7c1cc33c26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e081a63-ed78-4b88-8e50-1a7c1cc33c26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
p1=pd.read_csv("products.csv")

# %%
p1.head()
# Out:
#    'productno' 'productName' 'Description' 'isActive'        'createdDate'  \
# 0            1      Product1    pgqorighfa          Y  2017-04-03 07:58:55
# 1            2      Product2    lmndaaweth          Y  2017-09-21 12:38:31
# 2            3      Product3    urifeubrhh          Y  2017-09-08 10:32:12
# 3            4      Product4    rlpcjxfarp          Y  2017-05-22 05:29:27
# 4            5      Product5    hzcpozsgfc          Y  2017-02-02 08:40:29
#
#          'UpdatedDate'
# 0  2017-10-18 12:12:38
# 1  2017-10-18 12:12:38
# 2  2017-10-18 12:12:38
# 3  2017-10-18 12:12:38
# 4  2017-10-18 12:12:38

# %% [markdown]
# Usecase-2 Display only those customers from CSV_s1, who purchased more than 3 products
#
# ---

# %%
purchase=c1.groupby("'firstname'").nunique()

# %%
purchase[purchase["'custno'"]>3]["'custno'"]
# Out:
# 'firstname'
# Alan         4
# Alexandra    5
# Alyssa       4
# Andrea       5
# Anthony      5
#             ..
# Vicky        5
# Walter       4
# Wesley       5
# William      5
# Wyatt        5
# Name: 'custno', Length: 67, dtype: int64

# %% [markdown]
# Usecase-3 Display top 5 most demanded products from CSV_s1

# %%
t1["'productno'"].value_counts().head()
# Out:
# 'productno'
# 82     5
# 427    5
# 900    5
# 768    5
# 849    4
# Name: count, dtype: int64

# %% [markdown]
# Usecase-4 Display top 5 transactions amount
# from CSV_s1

# %%
sorted_t=t1.sort_values("'amount'",ascending=False)

# %%
sorted_t.head()
# Out:
#      'txnno'            'txndate'  'custno'  'amount'  'productno' 'spendby'
# 556      557  2017-10-18 12:31:46       670      4996          509      Card
# 305      306  2017-10-18 12:31:46       448      4992          427      Cash
# 574      575  2017-10-18 12:31:46       305      4981          549      Card
# 531      532  2017-10-18 12:31:46       230      4980          658      Card
# 232      233  2017-10-18 12:31:45       287      4966          685      Card

# %% [markdown]
# Usecase-5 Display distinct professions from CSV_s1

# %%
professions=c1["'profession'"].unique()

# %%
print("these are different professions:",professions)
# Out:
# these are different professions: ['B' 'S']

# %% [markdown]
# Usecase-6 Display highest age in CSV_s1 customer’s dataset

# %%
max_age=c1[["'firstname'","'age'"]].max()

# %%
print("the heighest age is",max_age["'age'"],"of person named",max_age["'firstname'"])
# Out:
# the heighest age is 64 of person named Zachary

# %% [markdown]
# Usecase-7  Display custno, gender, age, profession, contactno, productno, productName,
# txndate, spendby, amount from CSV_s1 for custno = 923

# %%
 t1[t1["'custno'"]==923]
# Out:
#      'txnno'            'txndate'  'custno'  'amount'  'productno' 'spendby'
# 0          1  2017-10-18 12:31:45       923      2559          376      Card
# 334      335  2017-10-18 12:31:46       923      2303          113      Card
# 932      933  2017-10-18 12:31:46       923      4553          644      Cash

# %% [markdown]
# Usecase-8 Load all three PSV (pipe separated values) dataset in Pandas Data frames and
# display first 5 records.

# %%
from google.colab import files

# %%
import pandas as pd

# %%
psv1=files.upload()
# Out:
#      <input type="file" id="files-9addddac-7ada-45df-80ce-80a49328a093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9addddac-7ada-45df-80ce-80a49328a093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_psv1= pd.read_csv("customers.txt")

# %%
df_psv1.head()
# Out:
#   1|Leslie|Bass|F|27|B|37307|endslost@everyma1l.org|Gibson|Dellwood|Y|2017-09-21 12:38:22|2017-10-18 12:12:28
# 0  2|Judy|Burks|M|53|S|84759|rfleming@hotma1l.co....
# 1  3|Marsha|Doyle|F|48|B|80932|arethe53@ma1lbox.n...
# 2  4|Alexis|Battle|M|27|S|71701|ofcame@ma1lbox.or...
# 3  5|Martha|Combs|F|49|B|83947|camedied@everyma1l...
# 4  6|Marilyn|Nguyen|M|57|S|72274|discoveredlist82...

# %%
json1=files.upload()
# Out:
#      <input type="file" id="files-b653a1d7-4389-4fd0-89ff-80bedac7e1ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b653a1d7-4389-4fd0-89ff-80bedac7e1ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import json

# Read the JSON file line by line and load each JSON object
data = []
with open('customers.json') as f:
    for line in f:
        data.append(json.loads(line))

# Convert the list of JSON objects to a DataFrame
df_json = pd.DataFrame(data)
df_json.head()
# Out:
#    custno  firstname lastname  gender  age          profession      contactNo  \
# 0       1        Dai    Noble       2   53     Human Resources  1644101928099
# 1       2        Kay     Wise       2   26    Public Relations  1674031917099
# 2       3       Amir     Pace       1   43  Customer Relations  1636050509999
# 3       4  Sebastian    Lopez       2   32  Customer Relations  1666010108899
# 4       5      Brian   Maddox       1   40   Quality Assurance  1646080399299
#
#                         emailId             city       state  isActive  \
# 0  eu.lacus.Quisque@loremac.com           Berlin      Berlin         1
# 1          ridiculus@Sednunc.ca        Oldenzaal  Overijssel         2
# 2    quam.Pellentesque@erat.edu          Cobourg     Ontario         2
# 3           magna@venenatis.net       Te Awamutu          NI         1
# 4         ac.facilisis@Duis.com  Greater Sudbury     Ontario         2
#
#   createdDate UpdatedDate
# 0  2017-03-01  2018-08-25
# ...

# %%
json2=files.upload()
# Out:
#      <input type="file" id="files-6ece6fd6-07f7-4939-a982-f6d14abd5b8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ece6fd6-07f7-4939-a982-f6d14abd5b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import json
data=[]
with open("products.json") as p:
  for lines in p:
    data.append(json.loads(lines))

df_json2 = pd.DataFrame(data)
df_json2.head()
# Out:
#    productno     productName Description  isActive createdDate UpdatedDate
# 0        100        Vauxhall        four         2  2016-11-21  2017-11-09
# 1        101          Toyota         six         2  2017-10-03  2017-11-13
# 2        102  General Motors         two         1  2017-09-18  2017-11-03
# 3        103         Renault       eight         2  2017-10-05  2017-11-13
# 4        104        Kenworth       three         1  2017-05-03  2017-11-04

# %%
json3=files.upload()
# Out:
#      <input type="file" id="files-cdffe379-a7c0-4ca0-8802-9e688c2bf73b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdffe379-a7c0-4ca0-8802-9e688c2bf73b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import json
data=[]
with open("transactions.json") as t:
  for lines in t:
    data.append(json.loads(lines))
df_t=pd.DataFrame(data)
df_t.head()
# Out:
#    txnno     txndate  custno  amount  productno  spendby
# 0      1  2018-07-31      71     181         19        2
# 1      2  2017-04-02      44     401         48        2
# 2      3  2018-01-31      45    1808         44        2
# 3      4  2018-04-02      62      65         22        2
# 4      5  2017-08-17      88    1149         74        2

# %% [markdown]
# Usecase-10  Load all three XML datasets in Pandas Data frames and display first 5 records.

# %%
from google.colab import files
import pandas as pd

# %%
xml1=files.upload()
# Out:
#      <input type="file" id="files-d25fb47f-859d-44f3-ab5c-7cc67341c963" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d25fb47f-859d-44f3-ab5c-7cc67341c963">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_mxl1=pd.read_xml("customers.xml")

# %%
df_mxl1.head()
# Out:
#    custno firstname  lastname  gender  age          profession      contactNo  \
# 0       1    Teegan   Hubbard       2   33     Human Resources  1681121691699
# 1       2    Deacon    Briggs       2   54  Customer Relations  1631082682999
# 2       3   Mallory   Shelton       1   57  Customer Relations  1627011572699
# 3       4     Quinn  Clements       2   43     Media Relations  1618122268999
# 4       5    Arthur     Hurst       2   41        Tech Support  1681021022799
#
#                           emailId             city         state  isActive  \
# 0       nibh.Quisque@placerat.com       Galashiels  Selkirkshire         1
# 1      facilisis.eget@Nullaeu.com  Lens-Saint-Remy            LU         1
# 2    Curabitur.ut@Nullatempor.edu      North Shore            NI         1
# 3  metus.Vivamus.euismod@urna.edu          Heredia             H         1
# 4             in@commodoipsum.org        San Diego       Cartago         2
#
#   createdDate UpdatedDate
# ...
